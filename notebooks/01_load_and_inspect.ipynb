# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from src.neuroengine.io import load_tiff
from src.neuroengine.preprocess import compute_mean_image, compute_baseline, compute_dff

import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from src.neuroengine.io import load_tiff
#       2 from src.neuroengine.preprocess import compute_mean_image, compute_baseline, compute_dff
#       4 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'src'

# %%
data = np.random.rand(100, 64, 64)
data.shape

# %%
plt.imshow(data[0], cmap="gray")
plt.title("First frame")
plt.colorbar()
plt.show()

# %%
mean_img = np.mean(data, axis=0)

plt.imshow(mean_img, cmap="gray")
plt.title("Mean image")
plt.colorbar()
plt.show()

# %%
pixel_trace = data[:, 20, 30]

plt.plot(pixel_trace)
plt.title("Pixel trace at (20, 30)")
plt.xlabel("Time")
plt.ylabel("Intensity")
plt.show()
